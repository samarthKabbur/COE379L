# %%
import numpy as np

# %% [markdown]
# Need three things for a neural net:
# 1. Create perceptrons of dimensions with weights and biases
# 2. Create layers with number of perceptrons and a non linear activation function
# 3.

# %%
def create_perceptron(dim):
    return np.random.random(dim+1)

# %%
def create_layer(num_perceptrons, dim, activation_function):
    layer = []
    for i in range(num_perceptrons):
        layer.append({"weights":create_perceptron(dim), "activation_function": activation_function})
    return layer

# %%
def sigmoid(x):
    return 1.0 / (1 + np.exp(-x))

# %%
import matplotlib.pyplot as plt
import math
x = np.linspace(-100, 100, 1000)
plt.plot(x, sigmoid(x))
plt.xlabel("x")
plt.ylabel("sigmoid(x)")
plt.show()

# %% [markdown]
# Sigmoid is differentiable
# maps alsmost all values to very close to 0 or very close to 1

# %%
l1 = create_layer(5, 3, sigmoid)
